# %%
# %run network.ipynb
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)
x_train = mnist.train.images
y_train = mnist.train.labels
x_test = mnist.test.images
y_test = mnist.test.labels
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz

# %%
training_samples = [np.reshape(x,(784,1)) for x in x_train]
training_result = [np.reshape(y,(10,1)) for y in y_train]

testing_samples = [np.reshape(x,(784,1)) for x in x_test]
testing_result = [np.reshape(y,(10,1)) for y in y_test]

# %%
# 3 layers
# Number of neurons (784 30 10)
# learning rate = 0.9
# Training times (epoch) = 10

net1 = Network([784,30,10])
net1.training(training_samples[:-1],training_result[:-1],0.9,10)
net1.testing(testing_samples[:5000],testing_result[:5000])
# Out:
# training loss -- 0.29326342196988286
# training loss -- 0.1765606466977408
# training loss -- 0.15340619974764677
# training loss -- 0.13777760795456326
# training loss -- 0.13042142185630012
# training loss -- 0.12472137029612751
# training loss -- 0.12181486122208755
# training loss -- 0.11498364855447471
# training loss -- 0.11133374091860315
# training loss -- 0.10933033646576061
# Testing Accuracy = 0.924

# %%
# 4 layers
# learning rate = 0.1
# Number of neurons (784 30 30 10)
# Training times (epoch) = 5

net2 = Network([784,30,30,10])
net2.training(training_samples[:-1],training_result[:-1],0.1,5)
net2.testing(testing_samples[:5000],testing_result[:5000])
# Out:
# training loss -- 0.45448926814512625
# training loss -- 0.2358116761466881
# training loss -- 0.19083052388923416
# training loss -- 0.166602622991505
# training loss -- 0.15053206849915457
# Testing Accuracy = 0.9132

# %%
# 3 layers
# learning rate = 3
# Number of neurons (784 30 10)
# Training times (epoch) = 10

net3 = Network([784,30,10])
net3.training(training_samples[:-1],training_result[:-1],3,10)
net3.testing(testing_samples[:5000],testing_result[:5000])
# Out:
# training loss -- 0.442168751574698
# training loss -- 0.33945913692079327
# C:\Users\vita7\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: RuntimeWarning: overflow encountered in exp
# training loss -- 0.29311603071936554
# training loss -- 0.2654904142299773
# training loss -- 0.24770437760495986
# training loss -- 0.2456177088863358
# training loss -- 0.22562550811283263
# training loss -- 0.21504697243732224
# training loss -- 0.21961800989718933
# training loss -- 0.21727198033815365
# Testing Accuracy = 0.843
